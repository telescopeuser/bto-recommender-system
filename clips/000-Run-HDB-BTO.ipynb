# %%
# !pip install pyclips flask flask-socketio eventlet simplejson pandas
# Out:
# ...
#     100% |████████████████████████████████| 1.1MB 372kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 92kB 1.2MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 409kB 546kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 81kB 1.1MB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 24.3MB 37kB/s eta 0:00:011�█████████▍                   | 9.5MB 64.6MB/s eta 0:00:01 | 20.9MB 64.2MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 51kB 104kB/s a 0:00:011
# ...
#     100% |████████████████████████████████| 71kB 54kB/s eta 0:00:011
# ...
#   Using cached Werkzeug-0.14.1-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 51kB 2.0MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 512kB 470kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for pyclips ... done
#   Stored in directory: /home/iss-user/.cache/pip/wheels/2e/f2/84/f9e064bc11b1214ba7f628f376ac8921299cdd6fdce9fa1bfb
# ...

# %%
# !python app.py
# Out:
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 493-597-337
# (8179) wsgi starting up on http://0.0.0.0:5000
# (8179) accepted ('127.0.0.1', 56998)
# 127.0.0.1 - - [14/Mar/2018 22:54:43] "GET /bto/units_booked HTTP/1.1" 200 8415 0.172143
# ('Client connected', 'b644a216815c4a998306ebf16e56d706')
# 127.0.0.1 - - [14/Mar/2018 22:54:43] "GET /socket.io/?EIO=3&transport=polling&t=1521039283904-0 HTTP/1.1" 200 381 0.019758
# What is your preferred area in this BTO sales launch?
# [('1', 'Eunos'), ('2', 'Punggol'), ('3', 'Sengkang'), ('4', 'Tampines'), ('5', 'No Preferences')]
# (8179) accepted ('127.0.0.1', 57000)
# 127.0.0.1 - - [14/Mar/2018 22:54:44] "GET /socket.io/?EIO=3&transport=polling&t=1521039284002-1&sid=b644a216815c4a998306ebf16e56d706 HTTP/1.1" 200 395 0.000242
# 127.0.0.1 - - [14/Mar/2018 22:54:44] "GET /socket.io/?EIO=3&transport=polling&t=1521039284151-2&sid=b644a216815c4a998306ebf16e56d706 HTTP/1.1" 200 215 0.000198
# ...
